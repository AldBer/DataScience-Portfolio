# %%
import os
import pandas as pd
import geopandas as gpd

properties = pd.read_csv("../data/raw/sp_properties_sample.csv")
districts = gpd.read_file("../data/processed/sp_distritos_processado.geojson")

# Merge dos dados
properties_gdf = gpd.GeoDataFrame(
    properties,
    geometry=gpd.points_from_xy(properties.longitude, properties.latitude)
)
print(districts.head)
# Out:
# <bound method NDFrame.head of    ds_codigo            ds_nome ds_sigla ds_areakm     ds_areamt  \
# 0         67        RIO PEQUENO      RPE     9.657    9657007.38
# 1         25  CIDADE TIRADENTES      CTI    14.939   14939046.96
# 2         46    JARDIM SAO LUIS      JDS    26.048   26047523.11
# 3         64         PONTE RASA      PRA     6.597    6596680.61
# 4         49          LIBERDADE      LIB     3.651    3651129.57
# ..       ...                ...      ...       ...           ...
# 91        56               PARI      PRI     2.730    2729940.52
# 92        52           MARSILAC      MAR   208.165  208164976.65
# 93        78                 SE      SEE     2.194    2193786.90
# 94        92      VILA MEDEIROS      VMD     7.856    7855942.18
# 95        82           TUCURUVI      TUC     9.441    9441317.18
#
#                                              geometry
# 0   POLYGON ((320567.46388 7394377.31244, 320581.1...
# ...
