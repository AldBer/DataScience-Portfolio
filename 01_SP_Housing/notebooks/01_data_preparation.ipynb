# %%
import os
import pandas as pd
import geopandas as gpd

properties = pd.read_csv("../data/sp_properties_sample.csv")
districts = gpd.read_file("../data/sp_distritos_processado.geojson")

# Merge dos dados
properties_gdf = gpd.GeoDataFrame(
    properties,
    geometry=gpd.points_from_xy(properties.longitude, properties.latitude)
)
